# %%
daily_sales = [12000, 15500, 9800, 21000, 17250]
for i in range(1, len(daily_sales)):
 print(f"Day {i}: {daily_sales[i]} FCFA")
# Out:
# Day 1: 15500 FCFA
# Day 2: 9800 FCFA
# Day 3: 21000 FCFA
# Day 4: 17250 FCFA

# %%
daily_sales = [12000, 15500, 9800, 21000, 17250]
for i in range(len(daily_sales)):
 print(f"Day {i + 1}: {daily_sales[i]} FCFA")

# i counted through the loop by hand and given that the line line starts at one, the first index will not be included since 
# python numbering starts at 0, and also if just the day i is printed, it will start at 0 so i + 1 is used
# Out:
# Day 1: 12000 FCFA
# Day 2: 15500 FCFA
# Day 3: 9800 FCFA
# Day 4: 21000 FCFA
# Day 5: 17250 FCFA

# %%
product_name = "Cooking Oil 5L"
price = 6500
quantity = 3
receipt_line = "Item: " + product_name + " | Total: " + price * quantity + "
FCFA"
print(receipt_line)
# Out:
#   Cell In[27], line 4
#     receipt_line = "Item: " + product_name + " | Total: " + price * quantity + "
#                                                                                ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
product_name = "Cooking Oil 5L"
price = 6500
quantity = 3
receipt_line = f"Item: {product_name} | Total:  {price * quantity} FCFA"
print(receipt_line)

# i read the message error and traced the error which was that int cannot be concantinated with strings so i used the 
# f-strings instead
# Out:
# Item: Cooking Oil 5L | Total:  19500 FCFA

# %%
quantity = 0
if quantity == 0:
 status = "Out of Stock"
elif quantity <= 10:
 status = "Low Stock"
else:
status = "Well Stocked"
print(f"Status: {status}")
# Out:
#   Cell In[28], line 7
#     status = "Well Stocked"
#     ^
# IndentationError: expected an indented block after 'else' statement on line 6

# %%
quantity = 10
if quantity == 0:
    status = "Out of Stock"
elif quantity <= 10:
    status = "Low Stock"
else:
    status = "Well Stocked"
print(f"Status: {status}")
# i read the error message which was an identation error and corrected it by identing correctly and testing again with
# different values.
# Out:
# Status: Low Stock

# %%
products = [
 {"name": "Rice 25kg Bag", "price": 15000, "quantity": 12},
 {"name": "Sugar 1kg", "price": 900, "quantity": 50},
 {"name": "Bread Loaf", "price": 700, "quantity": 30},
]
total_value = 0
for product in products:
 total_value = product["price"] * product["quantity"]
print(f"Total inventory value: {total_value} FCFA")
# Out:
# Total inventory value: 21000 FCFA

# %%
products = [
 {"name": "Rice 25kg Bag", "price": 15000, "quantity": 12},
 {"name": "Sugar 1kg", "price": 900, "quantity": 50},
 {"name": "Bread Loaf", "price": 700, "quantity": 30},
]
total_value = 0
for product in products:
    value = product["price"] * product["quantity"]
    total_value = total_value + value 
    # print(total_value)
print(f"Total inventory value: {total_value} FCFA")
# i coounted through the loop loop by hand and also adding an additional print statement in the loop to figure out what was wrong.
# Out:
# Total inventory value: 246000 FCFA

# %%
customer_count = "12"
total_sales = 186000
average_per_customer = total_sales / customer_count
print("Average sale per customer: " + average_per_customer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 customer_count = "12"
#       2 total_sales = 186000
# ----> 3 average_per_customer = total_sales / customer_count
#       4 print("Average sale per customer: " + average_per_customer)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
customer_count = 12
total_sales = 186000
average_per_customer = total_sales / customer_count
print(f"Average sale per customer: {average_per_customer}")
# i read the error messages inorder to fix it by changing the type and using f-stings.
# Out:
# Average sale per customer: 15500.0
